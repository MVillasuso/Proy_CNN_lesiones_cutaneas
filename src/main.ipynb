# %% [markdown]
# ### THE BRIDGE  - Data Science Bootcamp
# ## `Clasificación de Lesiones Cutáneas usando una Red Neuronal Convolucional (CNN) y Data Augmentation`
#
# #### Mónica Villasuso López -  Proyecto Final (Octubre 2020)

# %% [markdown]
# Referencias consultadas (para Data Augmentation):
# https://enmilocalfunciona.io/tratamiento-de-imagenes-usando-imagedatagenerator-en-keras/
# https://datasmarts.net/es/como-usar-imagedatagenerator-para-entrenar-una-cnn-en-keras/
# https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
# http://personal.cimat.mx:8181/~mrivera/cursos/aprendizaje_profundo/convnets_aumentadas/convnets_aumentadas.html
#
#
# Sociedad Americana contra el Cancer
# https://www.cancer.org/es/

# %% [markdown]
# ## Antecedentes. Contexto
# =================================
# La escogencia del proyecto final está relacionada con:
# 1) La necesidad de un proyecto personal donde se pudieran consolidar los conocimientos adquiridos durante la segunda parte del bootcamp (Analítica Avanzada - Machine Learning y Deep Learning).
# 2) La evaluación de alternativas y la disponibilidad de datos o información para llevarlas a cabo,
# 3) Un proyecto que además de académico me generara un interés particular, con lo cual la motivación para encararlo sería mayor.
#
# Por otro lado, personalmente siempre he tenido la preocupación por el daño que las radiaciones solares (y más aún en los últimos años) pueden generar en la piel. Es una realidad que en muchos casos este daño puede ser mortal (de hecho tengo dos referencias cercanas que han fallecido por esta razón) pero es también una realidad que este daño se puede minimizar, y mucho, si se hace un diagnóstico temprano.
# Son muchas las fuentes y publicaciones que hacen referencia a la revisión personal de las lesiones cutáneas siguiendo una regla básica.
# La **“Regla del ABCDE”** es recomendada para buscar algunos de los signos comunes de melanoma, que es una de las formas más mortales del cáncer de piel. Según esta regla hay que observar:
#
# A - **A**simetría
# Una parte de un lunar o mancha de nacimiento (angioma) no es igual a la otra.
# B - **B**orde
# Los bordes son irregulares, desiguales, con rebordes, o borrosos.
# C - **C**olor
# El color no es el mismo en todos lados y puede incluir matices de marrón o negro, a veces con zonas de color rosado, rojo, blanco o azul.
# D - **D**iánetro
# El lunar es más grande de ¼ de pulgada (0.6 cm) de ancho (aproximadamente el tamaño del borrador de un lápiz) aunque en ocasiones los melanomas podrían ser menores a este tamaño.
# E - **E**volución:
# El lunar está cambiando en cuanto a tamaño, forma o color.
#
# Debido a que muchas de estas señales eran visibles y detectables a través de una imagen, surgió la idea de validar si con un modelo de aprendizaje supervisado y entrenando una Red Neuronal Convolucional se podría llegar a una predicción. El resultado de la predicción tendría que ver con la posibilidad de que la lesión fuese ** Sospechosa ** (en cuyo caso se recomienda la revisión por un especialista) o ** Normal** .
#
# Las fases del proyecto se planificaron de la siguiente manera:
# 1) Alcance y Planificación del proyecto
# 2) Recolección y preparación de datos
# 3) Entrenamiento de varios modelos
# 4) Selección del mejor modelo y entonación de parámetros
# 5) Pruebas finales y conclusiones

# %% [markdown]
# ## Carga de Datos
# =================================
# Debido a que se trata de un caso de Aprendizaje supervisado, los datos se encuentran bien diferenciados y almacenados en directorios separados según la categorización. Para este problema se han dividido en:
# * Malignos: Fotografías de lunares, manchas o lesiones de la piel que luego de ser estudiadas han sido diagnosticadas como * Malignas (Sospechosas) *  , es decir, con algún tipo de melanoma o condición que amerite tratamiento con un especialista
#
# * Benignos: Fotografías de lunares, manchas o lesiones de la piel que luego de ser estudiadas han sido diagnosticadas como * Benignas (Normales) *  sin que ameriten especial revisión médica.
#
#
# ### `TOMA IMAGENES YA CONVERTIDAS A BLANCO Y NEGRO Y REDIMENSIONADAS`

# %% [markdown]
# Imports

# %%
# Manejo de archivos y directorios
import os
from os import listdir
from os.path import isfile, join
import time
sys.path.append("../src/utils")

# Básicas (álgebra, números aleatorios, carga de datos en dataframe, visualizacion)
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import random
from random import shuffle

# Manejo de imágenes
import imageio
import cv2

# Guardar los modelos
import json

# Analítica Avanzada
# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
# Redes Neuronales 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, Callback  
from tensorflow.keras.preprocessing.image import ImageDataGenerator ,img_to_array


#Modulos del proyecto
from utils import apis_tb as a_tb
from utils import folders_tb as f_tb
from utils import models_tb as mod_tb
from utils import mining_data_tb as m_tb
from utils import visualization_tb as v_tb

# %%
my_path = os.getcwd()  #Guarda en esta variable el path inicial del main del proyecto
SEED = 54

# %% [markdown]
# ### (1) Preprocesamiento de las imágenes

# %%
gray_folder = "gray"
resize_folder = "resize"
benig_rel_path ="../resources/Benignos" 
malig_rel_path = "../resources/Malignos"
# Nombres de las clases (target)
class_names = ['Maligno','Benigno']  # (0=Maligno, 1=Benigno)

# %% [markdown]
# #### Crear directorios con las imágenes en Blanco y Negro y redimensionadas para el análisis
# `NOTA: Sólo debe ejecutarse una vez. Luego de que las imágenes estén creadas en disco se usan así las siguientes veces`

# %%
#m_tb.preparar_datos(my_path,benig_rel_path,gray_folder, resize_folder)
#m_tb.preparar_datos(my_path,malig_rel_path,gray_folder, resize_folder)

# %% [markdown]
# ## (2) Carga de imágenes requeridas para el modelo

# %%
tipo_lunar=[]        #Lista donde se cargaran las expresiones corresp a las fotos (0 - Maligno, 1 Benigno)
X_data_img =[]
bgr_path= benig_rel_path+ "/"+ gray_folder + "/" + resize_folder
mgr_path= malig_rel_path+ "/"+ gray_folder + "/" + resize_folder

# %%
X_data_img , tipo_lunar = m_tb.lista_img (X_data_img,tipo_lunar, 1,  my_path, bgr_path)
X_data_img , tipo_lunar = m_tb.lista_img (X_data_img,tipo_lunar, 0,  my_path, mgr_path)

# %%
# (Lista con los nombres de todas las fotos para entrenar el modelo)
print("Imagenes: ", len(X_data_img), " - Clasif: ", len(tipo_lunar))
# Out:
# Imagenes:  303  - Clasif:  303

# %%
random.seed(SEED)
#Shuffle de las 2 listas (conservando la relacion)
mapindexpos = list(zip(X_data_img,tipo_lunar))
random.shuffle(mapindexpos)
X_data_img,tipo_lunar = zip(*mapindexpos)

# %% [markdown]
# #### Preparación de los datos para ajustar el modelo de CNN

# %%
# Convertir la lista a np array
X = np.squeeze(X_data_img)
# Normalizacion de los datos
X = X.astype('float32')
X /= 255

# %% [markdown]
# ## (3) Conjuntos de Entrenamiento y Test para el modelo
# 85% para el conjunto de Train (considerando 20% de este para cross_validation) y el resto (15%) para Test

# %%
# Setting del tamaño del conjunto de entrenamiento
t_size=0.85
train_size = int(len(X) * t_size)

# %%
# Partición del conjunto de entrenamiento y test para entrenar el modelo
(train_images, train_labels), (test_images, test_labels) = (X[:train_size],np.array(tipo_lunar[:train_size])) , (X[train_size:] , np.array(tipo_lunar[train_size:]))

# %%
train_images.shape, train_labels.shape, test_images.shape, test_labels.shape
# Out:
# ((257, 48, 48), (257,), (46, 48, 48), (46,))

# %%
train_images_gr = train_images.reshape(train_images.shape[0], 48, 48, 1)
test_images_gr = test_images.reshape(test_images.shape[0], 48, 48, 1)

print("train_images_gr shape:", train_images_gr.shape)
print("test_images_gr shape:", test_images_gr.shape)
# Out:
# train_images_gr shape: (257, 48, 48, 1)
# test_images_gr shape: (46, 48, 48, 1)

# %%
# Muestra las primeras 36 imagenes del conjunto de entrenamiento 
v_tb.plot_img(train_images,train_labels,6,class_names, "../reports/", "train_img")

# %% [markdown]
# ## (4) MODELO - CNN

# %%
EPOCHS= 100
BSIZE = 48
PAT_VAL = 10

# %% [markdown]
# EL MEJOR accuracy se alcanzó con la siguientes características:
#
# Settings:
# Random seed = 54
# %Train = 85%  - % Test = 15%
# %Valid = 20%
# ----------
# Función de activación --> RELU   (en todas las capas)
# Optimizador --> Adam
# ----------
# Una CNN con:
#     - 1 capa convolutiva con 8 neuronas
#     - 1 capa convolutiva con 16 neuronas
#     - 1 MaxPool quedando las dimensiones de la imagen a la mitad
#     - 1 dropout 0.25
#     - 1 capa convolutiva con 32 neuronas
#     - 1 MaxPool quedando las dimensiones de la imagen a la mitad
#     - 1 dropout 0.25
#     - 1 Flatten
#     - 1 dense con 32 neuronas
#     - 1 dense con 64 neuronas
#     - 1 dense con 2 (Softmax --> salida)

# %%
tf.config.run_functions_eagerly(True)

INPUT_SHAPE = (48,48,1)

model1 = keras.models.Sequential()

# First conv-pool layers - set 1
model1.add(keras.layers.Conv2D(filters=8, kernel_size=(3, 3), strides=(1, 1), 
activation="relu", padding="valid", input_shape=INPUT_SHAPE))
model1.add(keras.layers.Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="valid"))
model1.add(keras.layers.MaxPool2D(pool_size=(2, 2)))
model1.add(keras.layers.Dropout(rate=0.25))
model1.add(keras.layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), activation="relu", padding="valid"))
model1.add(keras.layers.MaxPool2D(pool_size=(2, 2)))
model1.add(keras.layers.Dropout(rate=0.25))

# Flatten layer
model1.add(keras.layers.Flatten())

# Dense layers
model1.add(keras.layers.Dense(units=32, activation="relu"))
model1.add(keras.layers.Dense(units=64, activation="relu"))
# Output layer
model1.add(keras.layers.Dense(units=2, activation="softmax"))
model1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 46, 46, 8)         80
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 44, 44, 16)        1168
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 22, 22, 16)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 20, 20, 32)        4640
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 10, 10, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                102432
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_14 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 110,562
# Trainable params: 110,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compilar el modelo
# Distintos valores probados para el optimizador (*los mejores) : (*adam, *RMSprop, AdaMax, Adadelta, Adagrad)
model1.compile(optimizer='Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=PAT_VAL, verbose=1, min_delta=1e-4)  
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=PAT_VAL, verbose=1, min_delta=1e-4)
callbacks_list = [early_stop, reduce_lr]

# %%
# Usaremos 20% de la data de entrenamiento para validar el desempeño de la red en cada epoch.
X_train, X_valid, y_train, y_valid = train_test_split(train_images_gr, train_labels, train_size=0.8)

# %%
augmenter = ImageDataGenerator(horizontal_flip=True,
                               rotation_range=20, 
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               zoom_range=0.2,
                               shear_range=0.1,
                               fill_mode='nearest')

# %%
# En caso que se quieran guardar en disco las imágenes generadas en cada EPOCH se usa este path
save_path = "../resources/DataAument/Gen_Model"

# %%
# Entrenamiento del modelo usando DATA Augmentation
history = model1.fit(augmenter.flow(X_train, y_train, batch_size=BSIZE
#,save_to_dir=save_path, save_prefix= "t_", save_format = "png"   #Si se quieren guardar en disco
 ),
                    validation_data=augmenter.flow(X_valid, y_valid, batch_size=BSIZE),
                    steps_per_epoch= len(X_train) // BSIZE,
                    epochs=EPOCHS, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 232ms/step - loss: 0.6821 - accuracy: 0.5478 - val_loss: 0.6884 - val_accuracy: 0.5385
# Epoch 2/100
# 4/4 [==============================] - 1s 210ms/step - loss: 0.6973 - accuracy: 0.5987 - val_loss: 0.6913 - val_accuracy: 0.4615
# Epoch 3/100
# 4/4 [==============================] - 1s 246ms/step - loss: 0.6792 - accuracy: 0.5987 - val_loss: 0.6811 - val_accuracy: 0.5577
# Epoch 4/100
# 4/4 [==============================] - 1s 261ms/step - loss: 0.6599 - accuracy: 0.5669 - val_loss: 0.6751 - val_accuracy: 0.5192
# Epoch 5/100
# 4/4 [==============================] - 1s 234ms/step - loss: 0.6709 - accuracy: 0.5860 - val_loss: 0.6832 - val_accuracy: 0.5769
# Epoch 6/100
# 4/4 [==============================] - 1s 233ms/step - loss: 0.6518 - accuracy: 0.6178 - val_loss: 0.6716 - val_accuracy: 0.6731
# Epoch 7/100
# 4/4 [==============================] - 1s 219ms/step - loss: 0.6351 - accuracy: 0.6879 - val_loss: 0.6685 - val_accuracy: 0.5192
# Epoch 8/100
# 4/4 [==============================] - 1s 195ms/step - loss: 0.6571 - accuracy: 0.6306 - val_loss: 0.6666 - val_accuracy: 0.6346
# Epoch 9/100
# 4/4 [==============================] - 1s 220ms/step - loss: 0.6263 - accuracy: 0.6752 - val_loss: 0.6363 - val_accuracy: 0.6731
# Epoch 10/100
# 4/4 [==============================] - 1s 217ms/step - loss: 0.5898 - accuracy: 0.6875 - val_loss: 0.6375 - val_accuracy: 0.6923
# Epoch 11/100
# 4/4 [==============================] - 1s 182ms/step - loss: 0.5820 - accuracy: 0.7197 - val_loss: 0.6377 - val_accuracy: 0.6923
# Epoch 12/100
# 4/4 [==============================] - 1s 179ms/step - loss: 0.5626 - accuracy: 0.7516 - val_loss: 0.6265 - val_accuracy: 0.6731
# Epoch 13/100
# 4/4 [==============================] - 1s 237ms/step - loss: 0.5437 - accuracy: 0.7643 - val_loss: 0.6300 - val_accuracy: 0.6923
# Epoch 14/100
# 4/4 [==============================] - 1s 200ms/step - loss: 0.5574 - accuracy: 0.7325 - val_loss: 0.6300 - val_accuracy: 0.6731
# Epoch 15/100
# 4/4 [==============================] - 1s 213ms/step - loss: 0.5508 - accuracy: 0.7516 - val_loss: 0.6276 - val_accuracy: 0.7115
# Epoch 16/100
# 4/4 [==============================] - 1s 222ms/step - loss: 0.6222 - accuracy: 0.7134 - val_loss: 0.6377 - val_accuracy: 0.6731
# Epoch 17/100
# 4/4 [==============================] - 1s 222ms/step - loss: 0.5880 - accuracy: 0.7452 - val_loss: 0.6403 - val_accuracy: 0.6346
# Epoch 18/100
# 4/4 [==============================] - 1s 168ms/step - loss: 0.5396 - accuracy: 0.7834 - val_loss: 0.6128 - val_accuracy: 0.7115
# Epoch 19/100
# 4/4 [==============================] - 1s 209ms/step - loss: 0.5569 - accuracy: 0.7452 - val_loss: 0.6076 - val_accuracy: 0.7308
# Epoch 20/100
# 4/4 [==============================] - 1s 172ms/step - loss: 0.5266 - accuracy: 0.7707 - val_loss: 0.6134 - val_accuracy: 0.6923
# Epoch 21/100
# 4/4 [==============================] - 1s 262ms/step - loss: 0.5729 - accuracy: 0.7389 - val_loss: 0.6023 - val_accuracy: 0.7115
# Epoch 22/100
# 4/4 [==============================] - 1s 172ms/step - loss: 0.5649 - accuracy: 0.7389 - val_loss: 0.6223 - val_accuracy: 0.6346
# Epoch 23/100
# 4/4 [==============================] - 1s 219ms/step - loss: 0.5488 - accuracy: 0.7325 - val_loss: 0.6193 - val_accuracy: 0.7308
# Epoch 24/100
# 4/4 [==============================] - 1s 188ms/step - loss: 0.5566 - accuracy: 0.7396 - val_loss: 0.5988 - val_accuracy: 0.7500
# Epoch 25/100
# 4/4 [==============================] - 1s 208ms/step - loss: 0.5473 - accuracy: 0.7580 - val_loss: 0.6224 - val_accuracy: 0.7308
# Epoch 26/100
# 4/4 [==============================] - 1s 243ms/step - loss: 0.5626 - accuracy: 0.7448 - val_loss: 0.6206 - val_accuracy: 0.7115
# Epoch 27/100
# 4/4 [==============================] - 1s 186ms/step - loss: 0.5246 - accuracy: 0.7898 - val_loss: 0.6144 - val_accuracy: 0.6923
# Epoch 28/100
# 4/4 [==============================] - 1s 250ms/step - loss: 0.5308 - accuracy: 0.7604 - val_loss: 0.5999 - val_accuracy: 0.7308
# Epoch 29/100
# 4/4 [==============================] - 1s 223ms/step - loss: 0.5335 - accuracy: 0.7708 - val_loss: 0.5955 - val_accuracy: 0.7308
# Epoch 30/100
# 4/4 [==============================] - 1s 233ms/step - loss: 0.5729 - accuracy: 0.7197 - val_loss: 0.5998 - val_accuracy: 0.7115
# Epoch 31/100
# 4/4 [==============================] - 1s 210ms/step - loss: 0.5357 - accuracy: 0.7448 - val_loss: 0.5848 - val_accuracy: 0.7692
# Epoch 32/100
# 4/4 [==============================] - 1s 271ms/step - loss: 0.4994 - accuracy: 0.7898 - val_loss: 0.5932 - val_accuracy: 0.7308
# Epoch 33/100
# 4/4 [==============================] - 1s 193ms/step - loss: 0.5129 - accuracy: 0.8089 - val_loss: 0.5922 - val_accuracy: 0.7308
# Epoch 34/100
# 4/4 [==============================] - 1s 204ms/step - loss: 0.5371 - accuracy: 0.7643 - val_loss: 0.6012 - val_accuracy: 0.7115
# Epoch 35/100
# 4/4 [==============================] - 1s 179ms/step - loss: 0.5721 - accuracy: 0.7134 - val_loss: 0.5822 - val_accuracy: 0.7500
# Epoch 36/100
# 4/4 [==============================] - 1s 156ms/step - loss: 0.5194 - accuracy: 0.7898 - val_loss: 0.5881 - val_accuracy: 0.7500
# Epoch 37/100
# 4/4 [==============================] - 1s 207ms/step - loss: 0.5145 - accuracy: 0.7760 - val_loss: 0.5841 - val_accuracy: 0.7308
# Epoch 38/100
# 4/4 [==============================] - 1s 213ms/step - loss: 0.5118 - accuracy: 0.8025 - val_loss: 0.5900 - val_accuracy: 0.7500
# Epoch 39/100
# 4/4 [==============================] - 1s 182ms/step - loss: 0.5419 - accuracy: 0.7452 - val_loss: 0.5860 - val_accuracy: 0.7308
# Epoch 40/100
# 4/4 [==============================] - 1s 216ms/step - loss: 0.5504 - accuracy: 0.7580 - val_loss: 0.6171 - val_accuracy: 0.7115
# Epoch 41/100
# 4/4 [==============================] - 1s 262ms/step - loss: 0.5234 - accuracy: 0.7500 - val_loss: 0.5964 - val_accuracy: 0.7115
# Epoch 42/100
# 4/4 [==============================] - 1s 250ms/step - loss: 0.5583 - accuracy: 0.7516 - val_loss: 0.5936 - val_accuracy: 0.7115
# Epoch 43/100
# 4/4 [==============================] - 1s 210ms/step - loss: 0.5239 - accuracy: 0.7580 - val_loss: 0.6010 - val_accuracy: 0.7115
# Epoch 44/100
# 4/4 [==============================] - 1s 193ms/step - loss: 0.5136 - accuracy: 0.7962 - val_loss: 0.5750 - val_accuracy: 0.7115
# Epoch 45/100
# 4/4 [==============================] - 1s 180ms/step - loss: 0.5204 - accuracy: 0.7643 - val_loss: 0.5677 - val_accuracy: 0.7500
# Epoch 46/100
# 4/4 [==============================] - 1s 170ms/step - loss: 0.4874 - accuracy: 0.7962 - val_loss: 0.5900 - val_accuracy: 0.7500
# Epoch 47/100
# 4/4 [==============================] - 1s 283ms/step - loss: 0.4986 - accuracy: 0.8153 - val_loss: 0.5881 - val_accuracy: 0.7500
# Epoch 48/100
# 4/4 [==============================] - 1s 220ms/step - loss: 0.5008 - accuracy: 0.7656 - val_loss: 0.6073 - val_accuracy: 0.7115
# Epoch 49/100
# 4/4 [==============================] - 1s 332ms/step - loss: 0.5234 - accuracy: 0.7516 - val_loss: 0.5793 - val_accuracy: 0.7692
# Epoch 50/100
# 4/4 [==============================] - 1s 277ms/step - loss: 0.4934 - accuracy: 0.8177 - val_loss: 0.6121 - val_accuracy: 0.6731
# Epoch 51/100
# 4/4 [==============================] - 1s 201ms/step - loss: 0.5219 - accuracy: 0.7771 - val_loss: 0.6341 - val_accuracy: 0.6538
# Epoch 52/100
# 4/4 [==============================] - 1s 207ms/step - loss: 0.5356 - accuracy: 0.7707 - val_loss: 0.5747 - val_accuracy: 0.7115
# Epoch 53/100
# 4/4 [==============================] - 1s 205ms/step - loss: 0.4754 - accuracy: 0.7898 - val_loss: 0.5560 - val_accuracy: 0.7500
# Epoch 54/100
# 4/4 [==============================] - 1s 176ms/step - loss: 0.5747 - accuracy: 0.7389 - val_loss: 0.5931 - val_accuracy: 0.6731
# Epoch 55/100
# 4/4 [==============================] - 1s 250ms/step - loss: 0.5467 - accuracy: 0.7452 - val_loss: 0.5992 - val_accuracy: 0.7500
# Epoch 56/100
# 4/4 [==============================] - 1s 219ms/step - loss: 0.5546 - accuracy: 0.7516 - val_loss: 0.6480 - val_accuracy: 0.6154
# Epoch 57/100
# 4/4 [==============================] - 1s 206ms/step - loss: 0.4935 - accuracy: 0.8025 - val_loss: 0.5947 - val_accuracy: 0.6923
# Epoch 58/100
# 4/4 [==============================] - 1s 273ms/step - loss: 0.5084 - accuracy: 0.7580 - val_loss: 0.5581 - val_accuracy: 0.6923
# Epoch 59/100
# 4/4 [==============================] - 1s 262ms/step - loss: 0.5481 - accuracy: 0.7708 - val_loss: 0.5819 - val_accuracy: 0.7308
# Epoch 60/100
# 4/4 [==============================] - 1s 203ms/step - loss: 0.5194 - accuracy: 0.7643 - val_loss: 0.5846 - val_accuracy: 0.7500
# Epoch 61/100
# 4/4 [==============================] - 1s 250ms/step - loss: 0.4903 - accuracy: 0.7834 - val_loss: 0.6141 - val_accuracy: 0.7115
# Epoch 62/100
# 4/4 [==============================] - 1s 210ms/step - loss: 0.5090 - accuracy: 0.7771 - val_loss: 0.6015 - val_accuracy: 0.7500
# Epoch 63/100
# 4/4 [==============================] - ETA: 0s - loss: 0.5024 - accuracy: 0.7917
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 4/4 [==============================] - 1s 259ms/step - loss: 0.5024 - accuracy: 0.7917 - val_loss: 0.6215 - val_accuracy: 0.6538
# Epoch 00063: early stopping

# %%
test_loss, test_acc = model1.evaluate(test_images_gr,  test_labels, verbose=2)

print('\nTest accuracy:', round(test_acc,7)*100 , "%")
# Out:
# 2/2 - 0s - loss: 0.5362 - accuracy: 0.7826
#
# Test accuracy: 78.26087000000001 %

# %%
moment=time.localtime()
nfile = 'Grafico_{}_{}-{}-{}'.format(round(test_acc*100000),moment[2],moment[3],moment[4])
v_tb.plot_history(history,"../reports/", test_acc)
# Out:
# [INFO] Generando gráfico...

# %% [markdown]
# ### PREDICCIONES

# %%
predictions = model1.predict(test_images_gr)

# %%
v_tb.plot_test(test_images,test_labels,predictions,6,class_names,"../reports/", "test_results")

# %% [markdown]
# ### Resultados: Matriz de Confusión y Reporte de Clasificación

# %%
 #Genera la matriz de confusión y la guarda en un archivo. La retorna como dataframe
df_mc= v_tb.mat_confusion(predictions, test_labels, class_names,"../reports/","mat_conf")

# %%
# Carga una matriz de confusión ya generada y la muestra.
mat_df = f_tb.cargar_csv("../reports/mat_conf")
mat_df
# Out:
#          Maligno  Benigno
# Maligno       14        9
# Benigno        3       20

# %% [markdown]
# ### Reporte de Clasificación

# %%
 #Genera el reporte de clasificación y lo guarda en un archivo. Lo retorna como dataframe
 df_rc = v_tb.clasif_repor (predictions, test_labels, class_names, "../reports/", "rep_clasif")

# %%
df_rc
# Out:
#               precision    recall  f1-score   support
# Maligno        0.823529  0.608696  0.700000  23.00000
# Benigno        0.689655  0.869565  0.769231  23.00000
# accuracy       0.739130  0.739130  0.739130   0.73913
# macro avg      0.756592  0.739130  0.734615  46.00000
# weighted avg   0.756592  0.739130  0.734615  46.00000

# %%
# Carga un reporte de clasificación ya generado y lo muestra.
clasif_df=f_tb.cargar_csv("../reports/rep_clasif")
clasif_df
# Out:
#               precision    recall  f1-score   support
# Maligno        0.823529  0.608696  0.700000  23.00000
# Benigno        0.689655  0.869565  0.769231  23.00000
# accuracy       0.739130  0.739130  0.739130   0.73913
# macro avg      0.756592  0.739130  0.734615  46.00000
# weighted avg   0.756592  0.739130  0.734615  46.00000

# %% [markdown]
# ### GUARDAR EL MODELO

# %%
ubicacion ="../modelos"
mod_tb.guardar_modelo(model1, ubicacion, test_acc)
# Out:
# WARNING:tensorflow:From /Users/purbina/Library/Python/3.8/lib/python/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /Users/purbina/Library/Python/3.8/lib/python/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ../modelos/Model_0.80435_21-13-27/assets

# %% [markdown]
# ### CARGAR UN MODELO GUARDADO

# %%
ubicacion = "../modelos"
model_name = "Model_0.82609_16-18-16"
#model_name = "Model_0.76087_20-11-30"
#model_name = "Model_0.78261_20-18-20"
modelo_REF = mod_tb.cargar_modelo(ubicacion, model_name)

# %%
predictionsA = modelo_REF.predict(test_images_gr)
predictionsB = np.argmax(predictionsA, axis=1)
mcY = confusion_matrix(test_labels, predictionsB)
print('Matriz de confusión')
print(mcY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b35a872cd6b9> in <module>
# ----> 1 predictionsA = modelo_REF.predict(test_images_gr)
#       2 predictionsB = np.argmax(predictionsA, axis=1)
#       3 mcY = confusion_matrix(test_labels, predictionsB)
#       4 print('Matriz de confusión')
#       5 print(mcY)
#
# NameError: name 'test_images_gr' is not defined

# %%
print(classification_report(test_labels, predictionsB, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#      Maligno       0.75      0.78      0.77        23
#      Benigno       0.77      0.74      0.76        23
#
#     accuracy                           0.76        46
#    macro avg       0.76      0.76      0.76        46
# weighted avg       0.76      0.76      0.76        46

# %% [markdown]
# ### PRUEBA CON EL MODELO GUARDADO Y CARGADO

# %%
relpath = ('../resources/Casos')
nfoto = "f1a.png"
foto = relpath + "/"+ nfoto

# %%
res  = a_tb.predic_imagen(modelo_REF, foto, class_names,modif=True,mostrar=True, rjson= False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-59efb26b3db7> in <module>
# ----> 1 res  = a_tb.predic_imagen(modelo_REF, foto, class_names,modif=True,mostrar=True, rjson= False)
#
# ~/Desktop/THE_BRIDGE/DS_MVL/PROYECTOS/projects/final/src/utils/apis_tb.py in predic_imagen(modelo, pimagen, cnames, modif, mostrar, rjson)
#      14     """
#      15     if modif:
# ---> 16         foto_red = f_tb.preparar_imagen(pimagen,48)
#      17         imagen = f_tb.formatear_imagen(foto_red,48)
#      18     else:
#
# ~/Desktop/THE_BRIDGE/DS_MVL/PROYECTOS/projects/final/src/utils/folders_tb.py in preparar_imagen(imagen, dimension)
#      29         Retorna la foto modificada
#      30     """
# ---> 31     imagen_orig=imageio.imread(imagen)
#      32     img_byn = imagen_orig[:, :, 0]       # Foto en Blanco y Negro
#      33     img_red= cv2.resize(img_byn,(dimension,dimension))   # Foto reducida a 48x48
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     263
#     264     # Get reader and read first
# --> 265     reader = read(uri, format, "i", **kwargs)
#     266     with reader:
#     267         return reader.get_data(0)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/imageio/core/functions.py in get_reader(uri, format, mode, **kwargs)
#     170
#     171     # Create request object
# --> 172     request = Request(uri, "r" + mode, **kwargs)
#     173
#     174     # Get format
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/imageio/core/request.py in __init__(self, uri, mode, **kwargs)
#     122
#     123         # Parse what was given
# --> 124         self._parse_uri(uri)
#     125
#     126         # Set extension
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/imageio/core/request.py in _parse_uri(self, uri)
#     258                 # Reading: check that the file exists (but is allowed a dir)
#     259                 if not os.path.exists(fn):
# --> 260                     raise FileNotFoundError("No such file: '%s'" % fn)
#     261             else:
#     262                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/Users/purbina/Desktop/THE_BRIDGE/DS_MVL/PROYECTOS/projects/final/resources/Casos/f1.png'

# %%
res  = a_tb.predic_imagen(model1, foto, class_names,modif=True,mostrar=True, rjson= False)

# %%
# Predicción mostrando la imagen y el resultado
res  = a_tb.predic_imagen(modelo_REF, foto, class_names,modif=True,mostrar=True, rjson= False)

# %%
# Predicción en formato JSON
res  = a_tb.predic_imagen(modelo_REF, foto, class_names,modif=True,mostrar=True, rjson= True)
res
# Out:
# '{"Maligno":{"0":0.5113120079},"Benigno":{"0":0.4886880219}}'
